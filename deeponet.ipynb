# %% [markdown]
# ---
# title: DeepONets & Interest-Rate Curve Construction
#
# date: 2025-01-07
# authors:
#   - name: Jose Melo
# ---

# %% [markdown]
# It turns out -perhaps not so surprising nowadays- that we can train neural networks to take market quotes (deposits, FRAs/futures, swaps, $\ldots$) and produce a discount curve such that those same quotes are repriced correctly. On paper this sounds straightforward: learn a mapping from inputs to discount factors. In practice, it is a bit more subtle. In this post I'll explain the characteristics of the problem of curve construction, why I think a data-driven approach can be an interesting and how it can be implemented with neural networks.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import numpy as np
import pandas as pd
import plotly
import plotly.io as pio


from plots import *
from solvers import *
from utils import *

torch.manual_seed(0)
DEVICE = torch.device('cpu')  # change to 'cuda' if you have a GPU
DTYPE = torch.float64
pio.renderers.default = "plotly_mimetype+notebook_connected"

# Load market data
market_rates_df = pd.read_excel("swaps.xlsx", index_col='date', parse_dates=['date'])
market_rates_df = market_rates_df.sort_index().dropna()
market_rates_df /= 100

# %% [markdown]
# # Lets recap some definitions
#
# Before jumping into the implementation, I think it is worth taking a second to review a bit about interest-rate modeling. Starting with interest-rate swaps, in general their price can be described by the formula
#
# $$
# \Pi_t
# =
# N\left(
# \underbrace{\sum_{i=1}^{n}\alpha_i\,P(t,T_i)\,F(t;T_{i-1},T_i)}_{\text{PV floating leg}}
# -
# \underbrace{K\sum_{i=1}^{n}\alpha_i\,P(t,T_i)}_{\text{PV fixed leg}}
# \right),
# $$
#
# where $N$ is the notional, $K$ is the fixed rate, $\alpha_i$ is the year fraction (accrual factor) of the $i$-th coupon, $T_i$ are the payment dates, and $P(t,T)$ is the discount factor. Assuming a *single-curve* framework (for simplicity), the forward rate for the period $[T_{i-1},T_i]$ is the (simple) forward rate $F(t;T_{i-1},T_i)$. If the swap is entered at par, we can impose $\Pi_t=0$ and obtain the par swap rate
#
# $$
# S(t)=K^{\star}(t)=
# \frac{\sum_{i=1}^{n}\alpha_i\,P(t,T_i)\,L(t;T_{i-1},T_i)}
# {\sum_{i=1}^{n}\alpha_i\,P(t,T_i)}.
# $$
#
# Once we obtain each discount factor via bootstrapping, we recover forward rates through
#
# $$
# F(t;T_{i-1},T_i)
# =
# \frac{1}{\alpha_i}\left(\frac{P(t,T_{i-1})}{P(t,T_i)}-1\right).
# $$
#
# ## Curve characteristics
#
# Given these definitions and identities, we now highlight what mathematical properties we *would like* these components to have:
#
# - Strictly positive discount factors $P(t,T)>0$: otherwise we would be allowing prices that could be absurd, such as negative values for a risk-free instrument, which swaps generally are.
# - Reasonable monotonicity: we expect monotonicity in discount curves if we assume positive rates. If we allow negative rates, we still want some degree of monotonicity to avoid oscillations in forward rates.
# - Smoothness: this matters because we want to be able to compute **instantaneous forward rates**.
#
# Indeed, once we have $P(t,T)$ for all $T$, we can define the instantaneous forward rate as
#
# $$
# f(t,T)=-\frac{\partial}{\partial T}\log P(t,T).
# \tag{1}
# $$
#
# Clearly, the instantaneous forward rate requires $P(t,T)$ to be differentiable in $T$ and smooth enough to avoid “jumps” in forward rates. The idea is to prevent small kinks in $\log P$ from turning into a significant jump in $f$, or a small oscillation from turning into a saw-tooth-shaped forward curve. In practice, unreasonable instantaneous forward curves are not just an aesthetic issue: they can generate unrealistic carry/roll-down profiles and make model calibration harder.
#
# Now, where do discount factors come from in the first place? In continuous time, discounting is linked to the short rate $r(t)$ by
#
# $$
# P(t,T)=\mathbb{E}_t^\mathbb{Q}\left[\exp\left(-\int_t^T r_u\,du\right)\right]
# =
# \mathbb{E}_t^\mathbb{Q}\left[\exp\left(-\int_t^T f(t,u)\,du\right)\right].
# $$
#
# At time $t=0$ for curve construction, we often treat $P(0,T)$ as the primitive object that we infer from market quotes. Once we have $P(0,T)$, we can obtain zero rates $z(0,T)$ via $P(0,T)=e^{-z(0,T)T}$ (in the continuously compounded case), and then instantaneous forwards using the derivative above [1]. Given this, the big question is: how do we obtain these instantaneous forward rates if we only have *discrete data points*?
#
# In practice, we only observe a finite set of instruments: deposits, futures/FRAs, swaps at a handful of maturities. These give us the pillars $\{T_1,\dots,T_m\}$ and values $\{P(0,T_j)\}$ (or equivalently zero rates, par rates, etc.). However, between pillars there are infinitely many curves that reproduce the same market prices, so we must *choose* an interpolation rule (and sometimes an extrapolation rule) in order to have a description of what happens inside each segment.
#
# In other words, because we have only a finite number of prices, there are *infinitely* many instantaneous forward curves consistent with the observed prices. For example, we could shift $f(0,T)$ up over one interval and down over another and still preserve the same integrals that determine the discount factors at the pillars. In a sense, the market helps us
# pin down the averages (expectations under $\mathbb{Q}$), and the curve builder's job is to choose a particular representation of the continuous phenomenon.
#
# ## Curves are determined by assumptions
#
# If we interpolate discount factors, we can preserve positivity naturally, especially if we interpolate $\log P$ (piecewise-linear interpolation in $\log P$ keeps $P>0$ by construction). If we interpolate zero rates, we often obtain a visually smooth curve, but we may inadvertently introduce non-local effects in the forwards. If we interpolate directly on instantaneous forwards, we can control smoothness very well, but we are making a strong structural assumption (we are literally specifying the object that we are interested in).
#
# In reality there is no free lunch: local, shape-preserving interpolations (piecewise linear, monotone convex) are robust and tend not to generate oscillations, but they can create kinks (lack of smoothness of $f$) that show up as jumps in forwards. Global, smooth interpolations (cubic splines) look very nice in zero rates, but they can overshoot between sparse pillars and create negative “humps” or ripples in $f$. In other words, interpolation is not a cosmetic detail, but a modeling choice about what is happening in the market between the quotes we actually observe.

# %%
plot_interpolation_examples(market_rates_df, market_rates_df.index[100])
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="76912bfe-6ef1-4fe9-b1c3-a0c666bac46a" class="plotly-graph-div" style="height:820px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("76912bfe-6ef1-4fe9-b1c3-a0c666bac46a")) {                    Plotly.newPlot(                        "76912bfe-6ef1-4fe9-b1c3-a0c666bac46a",                        [{"marker":{"color":"black","size":7},"mode":"markers","name":"Pillars","x":{"dtype":"f8","bdata":"F2zBFmzBZj8AAAAAAADQPwAAAAAAAOA\u002fAAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAACRA"},"y":{"dtype":"f8","bdata":"GrhV8ZP+7z9xMkAY+37vPxsEEEQo\u002fe4\u002fzZWGT4797T+uPG\u002f3YODrP\u002fYS0Muf\u002fOk\u002feo33DKE06D\u002fQ6JzvIYrmP7PavLwtj98\u002f"},"type":"scatter","xaxis":"x","yaxis":"y"},{"legendgroup":"log_linear_df","legendrank":10,"line":{"color":"#636EFA"},"mode":"lines","name":"Log-linear on DF","showlegend":true,"x":{"dtype":"f8","bdata":"F2zBFmzBZj8aNSrIVVCPP5cHUkUoeJw\u002fUHpH0xKkpD\u002fV8OWDEQyrP60zQhoIurA\u002f8G6Rcgfusz8zquDKBiK3P3XlLyMGVro\u002ftyB\u002fewWKvT\u002f8LedpAl\u002fAP57LDhYC+cE\u002fP2k2wgGTwz\u002fgBl5uAS3FP4KkhRoBx8Y\u002fI0KtxgBhyD\u002fE39RyAPvJP2V9\u002fB4Alcs\u002fBhsky\u002f8uzT+ouEt3\u002f8jOPySruZF\u002fMdA\u002f9XnNZ3\u002f+0D\u002fGSOE9f8vRP5YX9RN\u002fmNI\u002fZ+YI6n5l0z84tRzAfjLUPwiEMJZ+\u002f9Q\u002f2VJEbH7M1T+qIVhCfpnWP3rwaxh+Ztc\u002fS79\u002f7n0z2D8bjpPEfQDZP+xcp5p9zdk\u002fvSu7cH2a2j+N+s5GfWfbP17J4hx9NNw\u002fLpj28nwB3T\u002f\u002fZgrJfM7dP9A1Hp98m94\u002foAQydXxo3z+46aIlvhrgPyHRrBA+geA\u002fibi2+73n4D\u002fxn8DmPU7hP1qHytG9tOE\u002fwm7UvD0b4j8qVt6nvYHiP5M96JI96OI\u002f+yTyfb1O4z9jDPxoPbXjP8zzBVS9G+Q\u002fNNsPPz2C5D+cwhkqvejkPwWqIxU9T+U\u002fbZEtAL215T\u002fVeDfrPBzmPz5gQda8guY\u002fpkdLwTzp5j8OL1WsvE\u002fnP3YWX5c8tuc\u002f3\u002f1ogrwc6D9H5XJtPIPoP6\u002fMfFi86eg\u002fGLSGQzxQ6T+Am5AuvLbpP+iCmhk8Heo\u002fUWqkBLyD6j+5Ua7vO+rqPyE5uNq7UOs\u002fiiDCxTu36z\u002fyB8ywux3sP1rv1Zs7hOw\u002fwtbfhrvq7D8rvulxO1HtP5Ol81y7t+0\u002f+4z9Rzse7j9kdAczu4TuP8xbER476+4\u002fNEMbCbtR7z+dKiX0OrjvPwKJl29dD\u002fA\u002ft3wcZZ1C8D9rcKFa3XXwPx9kJlAdqfA\u002f01erRV3c8D+HSzA7nQ\u002fxPzs\u002ftTDdQvE\u002f8DI6Jh128T+kJr8bXanxP1gaRBGd3PE\u002fDA7JBt0P8j\u002fAAU78HEPyP3T10vFcdvI\u002fKelX55yp8j\u002fd3Nzc3NzyP5HQYdIcEPM\u002fRcTmx1xD8z\u002f5t2u9nHbzP62r8LLcqfM\u002fYZ91qBzd8z8Wk\u002fqdXBD0P8qGf5OcQ\u002fQ\u002ffnoEidx29D8ybol+HKr0P+ZhDnRc3fQ\u002fmlWTaZwQ9T9PSRhf3EP1PwM9nVQcd\u002fU\u002ftzAiSlyq9T9rJKc\u002fnN31Px8YLDXcEPY\u002f0wuxKhxE9j+I\u002fzUgXHf2PzzzuhWcqvY\u002f8OY\u002fC9zd9j+k2sQAHBH3P1jOSfZbRPc\u002fDMLO65t39z\u002fAtVPh26r3P3Wp2NYb3vc\u002fKZ1dzFsR+D\u002fdkOLBm0T4P5GEZ7fbd\u002fg\u002fRXjsrBur+D\u002f5a3GiW974P65f9pebEfk\u002fYlN7jdtE+T8WRwCDG3j5P8o6hXhbq\u002fk\u002ffi4Kbpve+T8yIo9j2xH6P+YVFFkbRfo\u002fmwmZTlt4+j9P\u002fR1Em6v6PwPxojnb3vo\u002ft+QnLxsS+z9r2KwkW0X7Px\u002fMMRqbePs\u002f1L+2D9ur+z+IszsFG9\u002f7PzynwPpaEvw\u002f8JpF8JpF\u002fD+kjsrl2nj8P1iCT9sarPw\u002fDHbU0Frf\u002fD\u002fBaVnGmhL9P3Vd3rvaRf0\u002fKVFjsRp5\u002fT\u002fdROimWqz9P5E4bZya3\u002f0\u002fRSzykdoS\u002fj\u002f6H3eHGkb+P64T\u002fHxaef4\u002fYgeBcpqs\u002fj8W+wVo2t\u002f+P8ruil0aE\u002f8\u002ffuIPU1pG\u002fz8z1pRImnn\u002fP+fJGT7arP8\u002fm72eMxrg\u002fz+n2JEUrQkAQIJSVA9NIwBAXMwWCu08AEA2RtkEjVYAQBDAm\u002f8scABA6jle+syJAEDEsyD1bKMAQJ4t4+8MvQBAeKel6qzWAEBSIWjlTPAAQCybKuDsCQFABhXt2owjAUDgjq\u002fVLD0BQLsIctDMVgFAlYI0y2xwAUBv\u002fPbFDIoBQEl2ucCsowFAI\\u002fstXBUCojJf5a3EFQIIGWvQLiwVAXIAc76u ...

# %% [markdown]
# ## A data-driven process
#
# Given the above, one might think that a data-driven approach is naturally superior to one where the user must impose structure to achieve uniqueness of the instantaneous forward curve; however, in this context neural networks have the same problem: from a finite set of quotes, there exist infinitely many compatible curves, and the model must choose one. The difference is that, instead of explicitly choosing an interpolation rule, we choose a *function class* (the architecture), a *fitting criterion* (a *loss function*), and some form of *regularization*.
#
# The question, then, is not whether a neural network eliminates modeling decisions, but *where* we are placing them and *how* we control them. The key is that we can learn these conditions from market observations: rather than hand-coding *how the curve should look* between pillars, we train a model to learn an *inductive bias* that reflects historical patterns (by currency, rate regime, liquidity, etc.). In practice, this translates into several potential advantages:
#
# - **Speed and computational scale**: Once trained, the network produces a curve (or its parameters) in a single evaluation. This is useful when curves must be built thousands of times (XVA, simulation, intraday) or when multiple curves are needed at once.
#
# - **Handling incomplete or noisy data**: In real data it is common to have missing maturities, clustered quotes, or *outliers*. Instead of relying on *ad hoc* heuristics (discarding, filling, manual smoothing), the model can be trained to be robust to these issues (e.g., via instrument *dropout* and losses that are less sensitive to *outliers*).
#
# - **Product-specific characteristics**: Deposits, FRAs/futures, and swaps “measure” and behave differently; likewise, different currencies may exhibit different curvature in the short-to-medium segment. In an NN pipeline, repricing can be implemented with differentiable product-specific layers, and the model can learn effective weights that reflect liquidity, *bid--ask*, and segment relevance.
#
# - **Temporal coherence and consistency with the forward model**: Stochastic interest-rate models typically take an initial instantaneous forward curve as input. For this reason, it is convenient to enforce that the constructed curve is “compatible” with the chosen dynamics, so that on day zero we start from a feasible state within the model itself. This consistency also reduces mismatches between “curve” and “model” and helps avoid constant recalibration of the parameters that govern the stochastic dynamics.
#
# - **Automatic differentiation**: Since everything is differentiable, we can compute sensitivities of outputs with respect to inputs instantly via automatic differentiation.
#
# In short, using an NN does not remove the non-uniqueness problem; what it does is turn it into an explicit choice of *prior* (architecture + regularization) that can be learned from data. The practical promise is not to obtain a “magically true” curve, but rather a fast, robust, and coherent builder that produces reasonable forwards without so much forced logic.

# %% [markdown]
# # Experiments
#
# Now let's move on to some implementations. For the goal of learning a bootstrapping function, I've chosen a particular architecture: ***DeepONets***, which are designed to learn mappings from functions to functions. All the code is available on my [GitHub page](https://github.com/jmelo11/).
#
# ### Aside: Training setup and data
#
# The data used was obtained from the Central Bank of Chile's website and includes IR swap curves from 2008 to 2025. As with other machine learning applications, we split the dataset into training and evaluation sets. Note that here we do not care if there is spill-over of information between days, since our goal is to train the model independently of the current-time variable $t$. In fact, we want to sample across different times so that our model learns plausible curve shapes from historical data.

# %%
# split into train and test
train_size = int(0.8 * len(market_rates_df))
train_market_rates_df = market_rates_df.sample(train_size, random_state=0)
test_market_rates_df = market_rates_df.drop(train_market_rates_df.index)

# %%
fig, _ = plot_market_swap_rates(train_market_rates_df)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a82ed53c-66d5-4b1f-8db4-f80737b0476c" class="plotly-graph-div" style="height:420px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a82ed53c-66d5-4b1f-8db4-f80737b0476c")) {                    Plotly.newPlot(                        "a82ed53c-66d5-4b1f-8db4-f80737b0476c",                        [{"mode":"lines+markers","name":"2016-04-25","x":{"dtype":"f8","bdata":"F2zBFmzBZj8AAAAAAADQPwAAAAAAAOA\u002fAAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAACRA"},"y":{"dtype":"f8","bdata":"7FG4HoXroT+DUUmdgCaiP\u002fusEnP7N6I\u002fBMa4DA6Boj8mKKUAzmSjP9qAdHFNGKQ\u002fwYMk0IG+pD\u002fgaFX3xFClP4DMWqXycac\u002f"},"type":"scatter"},{"mode":"lines+markers","name":"2018-08-03","x":{"dtype":"f8","bdata":"F2zBFmzBZj8AAAAAAADQPwAAAAAAAOA\u002fAAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAACRA"},"y":{"dtype":"f8","bdata":"mpmZmZmZmT+mCkYldQKaP\u002fbVnFEGz5o\u002fBYxMw5msnT+D8eNDoFehP+BsdWRPsaI\u002fHzyZ6Juqoz\u002fBmeSawWSkP33UPf8+iaY\u002f"},"type":"scatter"},{"mode":"lines+markers","name":"2025-05-30","x":{"dtype":"f8","bdata":"F2zBFmzBZj8AAAAAAADQPwAAAAAAAOA\u002fAAAAAAAA8D8AAAAAAAAAQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAUQAAAAAAAACRA"},"y":{"dtype":"f8","bdata":"mpmZmZmZqT8ofoy5awmpPwEwRt6JCag\u002f+6P2JD\u002fbpj+9ZEM3ybemP1xOcvrPKKc\u002fhuunNyOnpz8gaQmsKhioP+ApQs6Tbqo\u002f"},"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}]," ...

# %% [markdown]
# ## Today's Choice: DeepONets
#
# Training DeepONets can be viewed as learning an *operator* (a mapping from functions to functions) of the form
# $$
# \mathcal{G}:\; u(\cdot)\ \mapsto\ v(\cdot),
# $$
# where both the input and the output are functions. In our setting, the input is a *discretely observed* swap curve (pillar quotes across tenors), and the output is a *continuous* discount curve,
# $$
# T \mapsto P(0,T; t).
# $$
# Here we treat $t$ as a fixed parameter that simply indicates the evaluation date associated with the input quotes.
#
# A standard DeepONet splits the computation into two networks:
#
# - A **branch** network that reads the input quotes (the vector of pillar swap rates) and produces a latent representation $b \in \mathbb{R}^p$.
# - A **trunk** network that reads the query maturity $T$ and produces another representation $h(T)\in\mathbb{R}^p$.
#
# They are combined via an inner product,
# $$
# g(T) = \langle b,\; h(T)\rangle + \beta,
# $$
# so the model effectively learns a low-rank representation of the operator. In the implementation below we interpret the output as a continuously compounded zero rate $k(T)$ by applying a sigmoid transformation ,
# $$
# k(T)=k_{\min}+(k_{\max}-k_{\min})\,\sigma(g(T)),
# \qquad
# \sigma(x)=\frac{1}{1+e^{-x}},
# $$
# and we return the discount factor as
# $$
# P(0,T; t)=\exp\!\big(-T\,k(T)\big).
# $$
#
# This construction ensures $P(0,T; t)>0$ by definition. Monotonicity is not guaranteed automatically (since $k(T)$ is a learned function of $T$), so we control shape indirectly through regularization (e.g., smoothness/spikiness penalties and long-end constraints).

# %%
class DeepONetBootstrapper(nn.Module, CurveModel):    
    '''
    DeepONet-based bootstrapper for discount curve modeling.
    Uses a branch network to process market rates and a trunk network to process maturities.
    Note: CurveModel is an abstract base class defining the interface for curve models.
    '''
    def __init__(self, n_tenors: int, p: int = 16, hidden: int = 16):
        super().__init__()
        self.n_tenors = n_tenors
        
        self.branch = nn.Sequential(
            nn.Linear(1 * n_tenors, hidden, dtype=DTYPE, device=DEVICE),
            nn.Tanh(),
            nn.Linear(hidden, hidden, dtype=DTYPE, device=DEVICE),
            nn.Tanh(),
            nn.Linear(hidden, p, dtype=DTYPE, device=DEVICE),
        )
        self.trunk = nn.Sequential(
            nn.Linear(1, hidden, dtype=DTYPE, device=DEVICE),
            nn.Tanh(),
            nn.Linear(hidden, hidden, dtype=DTYPE, device=DEVICE),
            nn.Tanh(),
            nn.Linear(hidden, p, dtype=DTYPE, device=DEVICE),
        )
        self.bias = nn.Parameter(torch.zeros(1, dtype=DTYPE, device=DEVICE))
        self._b = None

    def set_curve(self, rates: torch.Tensor, tenors: torch.Tensor, **kwargs) -> None: 
        # in general we would use only rates, but keep tenors for interface consistency       
        if rates.ndim != 1 or tenors.ndim != 1:
            raise ValueError("rates and tenors must be 1D")
        if rates.numel() != self.n_tenors or tenors.numel() != self.n_tenors:
            raise ValueError(f"Expected n_tenors={self.n_tenors}")

        self._b = self.branch(rates)       

    def discounts(self, t: torch.Tensor) -> torch.Tensor:
        if self._b is None:
            raise RuntimeError("Call set_curve(rates, tenors) before pricing.")

        t = t.reshape(-1)
        h = self.trunk(t.unsqueeze(-1))                               
        g = (h * self._b).sum(dim=-1) + self.bias                     
        k = F.sigmoid(g)                # if k is like the integral of the fwd rate, sigmoid keeps it bounded
        df = torch.exp(-(t * k)).unsqueeze(-1) # this looks like exp(-t * rate)
        return df
    
model = DeepONetBootstrapper(n_tenors=market_rates_df.shape[1], p=32, hidden=32)
model.apply(weight_init_xavier)
# Out:
# DeepONetBootstrapper(
#   (branch): Sequential(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=32, bias=True)
#   )
#   (trunk): Sequential(
#     (0): Linear(in_features=1, out_features=32, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=32, out_features=32, bias=True)
#   )
# )

# %%
swaps = [Swap(c, dtype=DTYPE, device=DEVICE) for c in market_rates_df.columns] # utility function, takes a model and computes the par rate of a given maturity.
tenors = torch.tensor([str_tenor_to_days(c) for c in market_rates_df.columns], device=DEVICE, dtype=DTYPE)/360
solver = SSBroyden(model.parameters(), max_iter=2000, tolerance_change=1e-15, tolerance_grad=1e-15)
training_set = gen_training_set(train_market_rates_df, n_pairs=200, device=DEVICE, dtype=DTYPE)

# %% [markdown]
# ### Loss Functions
#
# For this particular case, we will focus on the following tasks:
#
# - Be able to reproduce swap par rates with a minimum degree of accuracy.
# - Be able obtain meaningful sensitivities (with AD).
# - Obtain a low-frequency representative from the infinite-dimensional family of instantaneous forward rate curves that match the same pillar prices.
#
# In order to achieve these goals, we train the neural network on loss functions that guide it to map swap quotes into discount factors while controlling what happens between (and beyond) the observed tenors.
#
# Throughout, let $t\in\{1,\dots,m\}$ index the observation dates (days) and $T_i,\ i\in\{1,\dots,n\}$ the swap tenors. The network produces a discount curve $P_\theta(0,T; t)$ for each date $t$, from which we compute the model-implied par rates $\widehat{S}_\theta(T_i; t)$.
#
# #### Swap Rate Loss
#
# The simplest, but most important, loss function is the swap rate loss. It measures the deviation from observed par swap rates:
#
# $$
# \mathcal{L}_{\text{swap}}(\theta)
# =
# \frac{1}{mn}\sum_{t=1}^{m}\sum_{i=1}^{n}
# \left(\widehat{S}_\theta(T_i; t)-S^{\text{mkt}}(T_i; t)\right)^2,
# $$
#
# where $S^{\text{mkt}}(T_i; t)$ denotes the market par rate at tenor $T_i$ on date $t$.
#
# #### Long-Term Forwards Loss
#
# Since we only observe instruments up to a final maturity $T_{\max}$, extrapolation beyond $T_{\max}$ requires an additional assumption. Here we impose a "flat-forward tail" by penalizing variation of the instantaneous forward curve after $T_{\max}$.
#
# Define the instantaneous forward rate for each date $t$ as
#
# $$
# f_\theta(T; t)=-\frac{\partial}{\partial T}\log P_\theta(0,T; t).
# $$
#
# Let $T_{\text{tail}}>0$ be the extrapolation horizon and define the average tail forward
#
# $$
# \bar f_\theta(t)
# =
# \frac{1}{T_{\text{tail}}}\int_{T_{\max}}^{T_{\max}+T_{\text{tail}}} f_\theta(u; t)\,du.
# $$
#
# Then the long-end loss is
#
# $$
# \mathcal{L}_{\text{tail}}(\theta)
# =
# \frac{1}{m\,T_{\text{tail}}}\sum_{t=1}^{m}
# \int_{T_{\max}}^{T_{\max}+T_{\text{tail}}}
# \left(f_\theta(T; t)-\bar f_\theta(t)\right)^2\,dT.
# $$
#
# This encourages the instantaneous forward rate to be approximately constant over the extrapolation region. If desired, one can replace $\bar f_\theta(t)$ by a fixed ultimate forward rate $f_\infty$ and penalize $\left(f_\theta(T; t)-f_\infty\right)^2$ instead.
#
# #### *Spikiness* Loss
#
# A naive smoothness penalty such as $\int (f_\theta'(T;t))^2\,dT$ would suppresses all the curvature and over-flatten the forward curve so we need to come up with another solution. Our goal is more specific: discourage *localized spikes* and high-frequency oscillations while allowing broad, low-frequency curvature. To capture spikiness, we penalize *excess* curvature of the forward curve, using the second derivative $f_\theta(T;t)$ and a tolerance threshold $\kappa>0$. Let
#
# $$
# x_\theta(T;t)=\left(\left|\frac{\partial^2}{\partial T^2}f_\theta(T; t)\right|-\kappa\right)_+,
# \qquad (y)_+=\max(y,0).
# $$
#
# We then define
#
# $$
# \mathcal{L}_{\text{spike}}(\theta)
# =
# \frac{1}{m\,(T_{\max}-T_{\min})}\sum_{t=1}^{m}
# \int_{T_{\min}}^{T_{\max}}
# \phi\!\left(x_\theta(T;t)\right)\,dT,
# $$
#
# where $\phi$ is a nonnegative penalty function. A possible choice could be, for example, the Huber penalty
#
# $$
# \phi(x)=
# \begin{cases}
# \frac{1}{2}x^2, & 0\le x\le \delta,\\[4pt]
# \delta\left(x-\frac{1}{2}\delta\right), & x>\delta,
# \end{cases}
# $$
#
# with $\delta>0$ controlling the transition between quadratic and linear growth. When $\left|f_\theta''(T;t)\right|\le \kappa$, we have $x_\theta(T;t)=0$ and the penalty vanishes, so low-frequency curvature is largely preserved; sharp kinks and oscillations (large $\left|f_\theta''\right|$) are penalized.
#
# #### Final Objective
#
# The final loss is given by a weighted combination of the above:
#
# $$
# \mathcal{L}(\theta)
# =
# \mathcal{L}_{\text{swap}}(\theta)
# +
# \lambda_{\text{tail}}\mathcal{L}_{\text{tail}}(\theta)
# +
# \lambda_{\text{spike}}\mathcal{L}_{\text{spike}}(\theta),
# $$
#
# where $\lambda_{\text{tail}}\ge 0$ and $\lambda_{\text{spike}}\ge 0$ control the trade-off between market fit, tail behaviour, and suppression of forward spikes.

# %%
def closure(*args, **kwargs) -> torch.Tensor:
    solver.zero_grad()
    n = len(training_set.rates_next)    
    sl,le,spl = 0.0,0.0,0.0
    for rates_next in training_set.rates_next:
        sl += swap_rate_loss(model, swaps, rates_next, tenors)*100        
        le += long_end_loss(model, rates_next, tenors, t_last=10.0, mode='ufr', ufr=0.03)
        spl += spike_loss(model, rates_next, tenors, huber_delta=0.2)

        if torch.any(torch.isnan(sl)) or torch.any(torch.isnan(le)) or torch.any(torch.isnan(spl)):
            raise ValueError("NaN encountered in loss computation.")
        
    sl = (sl / n).sum()
    le = (le / n).sum()
    spl = (spl / n).sum()
    total_loss = (sl + le + spl)
    total_loss.backward()
    print(f"Current loss: {total_loss.item():.6e}, Swap Loss: {sl.item():.6e}, Long-End Loss: {le.item():.6e}, Spikiness Loss: {spl.item():.6e}", end='\r')
    return total_loss

loss = solver.step(closure)
print(f"Final training loss: {loss:.6e}")
# Out:
# Final training loss: 1.203810e-05Loss: 8.523831e-06, Long-End Loss: 7.826688e-08, Spikiness Loss: 3.435998e-06

# %%
# save the model
# torch.save(model.state_dict(), "deeponet_bootstrapper_2.pth")

# load the model
model.load_state_dict(torch.load("deeponet_bootstrapper_2.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Results
#
# Qualitatively, the model tracks the market par swap curve very closely on the sample dates. The dashed model curves sit almost on top of the market markers across maturities, and the left-panel bar chart shows low residuals (basis points). With more time spend on training, this results can be improved a lot.

# %%
fig, dates = plot_swap_rates(model, test_market_rates_df)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="bf3a72db-940d-4dcb-9e61-ef815d350774" class="plotly-graph-div" style="height:680px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bf3a72db-940d-4dcb-9e61-ef815d350774")) {                    Plotly.newPlot(                        "bf3a72db-940d-4dcb-9e61-ef815d350774",                        [{"legendgroup":"2012-09-24","marker":{"color":"#636EFA"},"name":"2012-09-24","x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"iB+Yz6dYvb9kWBfH+jvFP9DjJ3cbPci\u002fYE4E+CfFwj+Ya1Ddn1nLv+YQyThhItA\u002fd25C552Y6b+yy45pTPLdP\u002fC3E34ffa+\u002f"},"type":"bar","xaxis":"x","yaxis":"y"},{"legendgroup":"2012-09-24","line":{"color":"#636EFA"},"marker":{"color":"#636EFA"},"mode":"markers+lines","name":"2012-09-24 (Market)","showlegend":false,"x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"mpmZmZmZqT+utmJ\u002f2T2pPwGimGziL6k\u002fA08WY4LJqD\u002flZxnuJ5OpP6iPMmn\u002fzqk\u002fmrFvpa5Gqj9ldiVqxaOqPx\u002fOJqCJ\u002fas\u002f"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"legendgroup":"2012-09-24","line":{"color":"#636EFA","dash":"dash"},"mode":"lines","name":"2012-09-24 (Model)","opacity":0.65,"showlegend":false,"x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"GcC48xiYqT\u002fXSFQkBkCpP82HbgVnLak\u002fGzhfb27LqD+f97b2WpCpP8tyDVBN0qk\u002fM47DsTI8qj9O9Pl456mqPzCZxkK7\u002fKs\u002f"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"legendgroup":"2016-02-12","marker":{"color":"#EF553B"},"name":"2016-02-12","x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"QGLJepbkxr+kq6T7VLvDPzgdLihhwbi\u002fbDwq8S3pz79SQ61RXoLXP9IMcGhcB9K\u002feFYTmRlE0z+YazdsX7LJv3x6HAdmm8G\u002f"},"type":"bar","xaxis":"x","yaxis":"y"},{"legendgroup":"2016-02-12","line":{"color":"#EF553B"},"marker":{"color":"#EF553B"},"mode":"markers+lines","name":"2016-02-12 (Market)","showlegend":false,"x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"7FG4HoXroT\u002fCFyZTBaOiP\u002fvlNlsS+aI\u002fBFDbqg5xoz8BD3CSFGikP0QJgpK\u002f36Q\u002fwHnS8GpXpT+mDTKrCOOlP91n43veCqg\u002f"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"legendgroup":"2016-02-12","line":{"color":"#EF553B","dash":"dash"},"mode":"lines","name":"2016-02-12 (Model)","opacity":0.65,"showlegend":false,"x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"XEjt\u002fizpoT+7E8mUCqWiP2Ti6eHN96I\u002fufe3JMptoz+6zUUi5WykP8u5q1gO3KQ\u002fvP7nCF1bpT9g3RkLZ+ClP87NI+0QCag\u002f"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"legendgroup":"2021-02-23","marker":{"color":"#00CC96"},"name":"2021-02-23","x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"VyZHvD+Iu78TzJRPad\u002fkP40\u002f2FKbhNo\u002fescNGS1r4z9eDqpCLPblv9VVGYmrIOs\u002fGdg4hDy037+Es8hMPqnWvyjRY0FA57G\u002f"},"type":"bar","xaxis":"x","yaxis":"y"},{"legendgroup":"2021-02-23","line":{"color":"#00CC96"},"marker":{"color":"#00CC96"},"mode":"markers+lines","name":"2021-02-23 (Market)","showlegend":false,"x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"exSuR+F6dD9gB84ZUdprP\u002fgP9zGltm8\u002f\u002fTfs3uQtdz+a6ItQTrOFP+TCTt5cqIw\u002fPLJWDoWtkT+6O2lcT+yUP\u002faMlgUhyp4\u002f"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"legendgroup":"2021-02-23","line":{"color":"#00CC96","dash":"dash"},"mode":"lines","name":"2021-02-23 (Model)","opacity":0.65,"showlegend":false,"x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"NIs1UZpvdD\u002fdl3quG2NsP3AbBQ3FBnA\u002fzXi8a4Ztdz+iS1LyUo+FP3iRDATP1Iw\u002fE\u002f5EpYigkT\u002f2lfQrB+OUPwzDabJLyJ4\u002f"},"type":"scatter","xaxis":"x2","yaxis":"y2"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color": ...

# %% [markdown]
# Now we compute the Jacobian of the implied zero rates with respect to the input swap rates. We can see whether each pillar quote produces a *local and sensible* influence on the zero curve (e.g., short-tenor bumps affecting mostly the short end, longer tenors driving the long end).

# %%
t_grid = np.linspace(1/360, 10.0, 100)
fig = plot_jacobian(model, test_market_rates_df, t_grid=t_grid, dates=dates)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="a1214764-d531-46b7-989e-c12add788dad" class="plotly-graph-div" style="height:770px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a1214764-d531-46b7-989e-c12add788dad")) {                    Plotly.newPlot(                        "a1214764-d531-46b7-989e-c12add788dad",                        [{"coloraxis":"coloraxis","hovertemplate":"t=%{y:.3f}y\u003cbr\u003epillar=%{x}\u003cbr\u003e\u0394z(t)=%{z:.3f} bp (per +1bp bump)\u003cextra\u003e\u003c\u002fextra\u003e","x":["1d","90d","180d","1y","2y","3y","4y","5y","10y"],"y":{"dtype":"f8","bdata":"F2zBFmzBZj9O317rAJC6P53ZAzv7NMo\u002fyiEsAPuQ0z\u002fFVtZieAfaP+BFwOL6PuA\u002fXmAVlDl64z\u002fbempFeLXmP1mVv\u002fa28Ok\u002f168UqPUr7T8q5bQsmjPwP2lyX4U50fE\u002fqP8J3thu8z\u002fnjLQ2eAz1PyUaX48XqvY\u002fZKcJ6LZH+D+jNLRAVuX5P+LBXpn1gvs\u002fIU8J8pQg\u002fT9f3LNKNL7+P880r9HpLQBAb3sEfrn8AEAOwlkqicsBQK0Ir9ZYmgJATU8EgyhpA0DslVkv+DcEQIzcrtvHBgVAKyMEiJfVBUDKaVk0Z6QGQGqwruA2cwdACfcDjQZCCECpPVk51hAJQEiEruWl3wlA58oDknWuCkCHEVk+RX0LQCZYruoUTAxAxp4Dl+QaDUBl5VhDtOkNQAQsru+DuA5ApHIDnFOHD0CiXCykESsQQPL\u002fVnp5khBAQqOBUOH5EECRRqwmSWERQOHp1vywyBFAMY0B0xgwEkCAMCypgJcSQNDTVn\u002fo\u002fhJAIHeBVVBmE0BvGqwruM0TQL+91gEgNRRAD2EB2IecFEBfBCyu7wMVQK6nVoRXaxVA\u002fkqBWr\u002fSFUBO7qswJzoWQJ2R1gaPoRZA7TQB3fYIF0A92CuzXnAXQIx7VonG1xdA3B6BXy4\u002fGEAswqs1lqYYQHxl1gv+DRlAywgB4mV1GUAbrCu4zdwZQGtPVo41RBpAuvKAZJ2rGkAKlqs6BRMbQFo51hBtehtAqtwA59ThG0D5fyu9PEkcQEkjVpOksBxAmcaAaQwYHUDoaas\u002fdH8dQDgN1hXc5h1AiLAA7ENOHkDXUyvCq7UeQCf3VZgTHR9Ad5qAbnuEH0DHPatE4+sfQIvwao2lKSBAM0KAeFldIEDbk5VjDZEgQIPlqk7BxCBAKzfAOXX4IEDSiNUkKSwhQHra6g\u002fdXyFAIiwA+5CTIUDKfRXmRMchQHLPKtH4+iFAGiFAvKwuIkDBclWnYGIiQGnEapIUliJAERaAfcjJIkC5Z5VofP0iQGG5qlMwMSNACQvAPuRkI0CxXNUpmJgjQFiu6hRMzCNAAAAAAAAAJEA="},"z":{"dtype":"f8","bdata":"slORwRIW8D\u002fbdqct2nRdv8tvygt+NIa\u002fS9zDU2dxjT\u002fOs2KZlwuTv+maa3CBiX6\u002fU+8CFXpprT8fx4YI7T+nvyLQK5I3R4A\u002fL7fcOCtm1z\u002fv1kbgNKbrPxN8KT0LMNC\u002fcV3bS6Z5kL9d6+SeoZGxP0SAsPGpo1g\u002f1q1rdNLCkL8TgrkSZgSsv+asxteHUYo\u002f7uy5WsTPpj91t4sgYFPxP7dxSaFtOsK\u002fy6w+RyzHlL8a6D98adeyP+fPgo3TCZW\u002fPmgojoaHpb9mbDGh+g\u002f\u002fvsiNJP4KplY\u002f9YkRzQVcrr97KsIS3aPrP3jbGw3ZRck\u002fVX01Moyijb85+pMtENqhP+O8CRsid6S\u002fy+nBy\u002fn9pr+8FZRAyByxP1heGllDr4K\u002fpeXPz4KLp79Kxqeq\u002fOzaP2b1PCL\u002fR+Q\u002ferSlbXXOg78PGjzOP2eOv+kSv1jOAoq\u002fWDf33TRCp7++GJMTIfO0P7G16+1HpYS\u002fHh1+fmBQkD8cEqG\u002fbaStv5sBXsj9JPA\u002fbSt6MOtqnT+rLIj5A0CyvyFMrvZWyLE\u002fVufhw2Abo7\u002fEws+3YJWYP6RWhjudEHi\u002fy3Cxgec9sj\u002fVC9bZsALYv6k9W71BNfI\u002f8HbJxdMTxT8kNa3gbWXCv\u002fbY2xFIZ8U\u002fx7K\u002fRl\u002f8Rb8FmsNPyA2zv\u002f+HuHl9sGe\u002f\u002fWuClf0Dtz\u002fixUf0+Jzcv1B8r4kCJO8\u002fkMJovvZz2T8u6T+0vcDKv+luoXPoUMw\u002f5344DmjzrD8mhk0zWpTDv92TpSh\u002fIWy\u002fTWYXQjKosj+aEtTI1aPVv+HNxvjpUuQ\u002fY3WjH4rT5D9ZYnHhNqTLv14ecNo8zcg\u002f2W3lTZYPuT96LpHflzDFv1ncKaKKbHm\u002fyA\u002fvBkZzoj8rvIwEvQHEv2bLPsJMatE\u002fYtSURgYV6z\u002fhWycm+6\u002fAv832bIQ2DbY\u002fsJmNvHsruD8EAiYxG4K6vw+Q2aGa6IC\u002fvfSrdqXHcr9TwWBCFESVP6EJo+R8dpu\u002ffXleJHFN7j+\u002fDN+F9MCnP9nooavqMrK\u002f\u002fI+epvYypT8OY4yZCGiGP8EdhUcZ2X6\u002fFJH6pXOIo7+drTegwcLDPxNix0O6ZM2\u002fLr7Q3CNl7j+wlkiWZGHSPxbN7422ZM6\u002fxyPbIsZrqL9R+V3OtXvCPyFWUhmJI3G\u002f4TUT0d93rr\u002ff2Gaq\u002fb3NP\u002fGNWgzkkNW\u002f4N9NSkTk6z+qVJZ1LLPhP0QhInNmI9i\u002fJ8oZFjZsw7\u002fsKdWPEwzRP\u002fAAIBOFoBY\u002fpMvqeH5ssb+sA1EAgIvQP\u002fSvK04yaNe\u002fetJT6Xei5z+Nzqdwc77pPx34Y4Qi2t2\u002f4lnEmyPvz79ignTVgMbWP8r2aXn25mw\u002fRjoY33LusL8A6yMgA2jPP4V+xvhHv9W\u002fvM7zBSyM4j9yjGRxRSbwPw\u002fhFaLHs9+\u002fZJa\u002f9H3E1L9J0h+Q7sfZPzgfG7R\u002f63U\u002f5cIX479Xrb\u002fKWYVGHqfKPxlJJsy9INK\u002fDx5lE2jg2j\u002ffTq2tw2DyP11E4bdv0d2\u002f8T7eNGSF17\u002fKalSRigbaP7wgD3fur3c\u002fSidgCSwUp7\u002fKMZuvd5XEP+72icHsm8u\u002fe5HaEK6+0T8TEa60bHnzP ...

# %% [markdown]
# Finally, we plot the instantaneous forward rates for the same dates shown above. The smooth and stable forward shapes suggest that the frequency and smoothness penalties are doing their job. The shaded extrapolation region also makes explicit where the curve is driven purely by model assumptions rather than by market instruments.
#
# One interesting feature is the hump that appears near the boundary of the information set. This hump emerges because the model must satisfy the imposed long-term forward rate: in order to anchor the long-run expectation, the curve is forced to bend upward (and then revert) close to the last liquid maturity. A large hump in this case indicates that the model is *over-correcting* in its choice of instantaneous forward curves to reconcile short-/medium-term market data with the long-term anchor. This is a warning sign that our chosen long-term level is likely inconsistent with the shapes implied by the observed curves.

# %%
fig = plot_instant_fwds(model, test_market_rates_df, t_max=12, dates=dates)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="f69670f3-3250-408f-a70f-07b3abcba532" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f69670f3-3250-408f-a70f-07b3abcba532")) {                    Plotly.newPlot(                        "f69670f3-3250-408f-a70f-07b3abcba532",                        [{"mode":"lines","name":"2012-09-24","x":{"dtype":"f8","bdata":"e4PqRiR7lD8PQvu4AnukP2BCgU5zuK4\u002fWaED8vF6tD+CocY8qpm5P6qhiYdiuL4\u002f6lAmaY3rwT\u002f+0IeO6XrEPxJR6bNFCsc\u002fJ9FK2aGZyT87Uaz+\u002fSjMP0\u002fRDSRauM4\u002fsai3JNuj0D+8aGg3ievRP8YoGUo3M9M\u002f0OjJXOV61D\u002faqHpvk8LVP+RoK4JBCtc\u002f7yjclO9R2D\u002f56IynnZnZPwOpPbpL4do\u002fDWnuzPko3D8XKZ\u002ffp3DdPyHpT\u002fJVuN4\u002fllSAAgIA4D+btNgL2aPgP6EUMRWwR+E\u002fpnSJHofr4T+r1OEnXo\u002fiP7A0OjE1M+M\u002ftZSSOgzX4z+69OpD43rkP79UQ026HuU\u002fxLSbVpHC5T\u002fJFPRfaGbmP850TGk\u002fCuc\u002f09Skchau5z\u002fZNP177VHoP96UVYXE9eg\u002f4\u002fStjpuZ6T\u002foVAaYcj3qP+20XqFJ4eo\u002f8hS3qiCF6z\u002f3dA+09yjsP\u002fzUZ73OzOw\u002fATXAxqVw7T8GlRjQfBTuPwv1cNlTuO4\u002fEVXJ4ipc7z+L2hD2AADwP40KvXrsUfA\u002fjzpp\u002f9ej8D+SahWEw\u002fXwP5WawQivR\u002fE\u002fl8ptjZqZ8T+a+hkShuvxP5wqxpZxPfI\u002fn1pyG12P8j+hih6gSOHyP6S6yiQ0M\u002fM\u002fpup2qR+F8z+pGiMuC9fzP6tKz7L2KPQ\u002frnp7N+J69D+xqie8zcz0P7Pa00C5HvU\u002ftgqAxaRw9T+4OixKkML1P7tq2M57FPY\u002fvZqEU2dm9j\u002fAyjDYUrj2P8L63Fw+Cvc\u002fxSqJ4Slc9z\u002fHWjVmFa73P8qK4eoAAPg\u002fzbqNb+xR+D\u002fP6jn016P4P9Ia5njD9fg\u002f1EqS\u002fa5H+T\u002fXej6Cmpn5P9mq6gaG6\u002fk\u002f3NqWi3E9+j\u002feCkMQXY\u002f6P+E675RI4fo\u002f42qbGTQz+z\u002fmmkeeH4X7P+nK8yIL1\u002fs\u002f6\u002fqfp\u002fYo\u002fD\u002fuKkws4nr8P\u002fBa+LDNzPw\u002f84qkNbke\u002fT\u002f1ulC6pHD9P\u002fjq\u002fD6Qwv0\u002f+hqpw3sU\u002fj\u002f9SlVIZ2b+P\u002f96Ac1SuP4\u002fAqutUT4K\u002fz8F21nWKVz\u002fPwcLBlsVrv8\u002fhR3ZbwAAAECHNS8y9igAQIhNhfTrUQBAiWXbtuF6AECKfTF516MAQIyVhzvNzABAja3d\u002fcL1AECOxTPAuB4BQJDdiYKuRwFAkfXfRKRwAUCSDTYHmpkBQJMljMmPwgFAlT3ii4XrAUCWVThOexQCQJdtjhBxPQJAmIXk0mZmAkCanTqVXI8CQJu1kFdSuAJAnM3mGUjhAkCe5TzcPQoDQJ\u002f9kp4zMwNAoBXpYClcA0ChLT8jH4UDQKNFleUUrgNApF3rpwrXA0CldUFqAAAEQKaNlyz2KARAqKXt7utRBECpvUOx4XoEQKrVmXPXowRArO3vNc3MBECtBUb4wvUEQK4dnLq4HgVArzXyfK5HBUCxTUg\u002fpHAFQLJlngGamQVAs330w4\u002fCBUC0lUqGhesFQLatoEh7FAZAt8X2CnE9BkC43UzNZmYGQLr1oo9cjwZAuw35UVK4BkC8JU8USOEGQL09pdY9CgdAv1X7mDMzB0DAbVFbKVwHQMGFpx0fhQdAwp393xSuB0DEtVOiCtcHQMXNqWQAAAhAxuX\u002fJvYoCEDI\u002fVXp61EIQMkVrKvheghAyi0CbtejCEDLRVgwzcwIQM1drvLC9QhAznUEtbgeCUDPjVp3rkcJQNClsDmkcAlA0r0G\u002fJmZCUDT1Vy+j8IJQNTtsoCF6wlA1gUJQ3sUCkDXHV8FcT0KQNg1tcdmZgpA2U0LilyPCkDbZWFMUrgKQNx9tw5I4QpA3ZUN0T0KC0DerWOTMzMLQODFuVUpXAtA4d0PGB+FC0Di9WXaFK4LQOQNvJwK1wtA5SUSXwAADEDmPWgh9igMQOdVvuPrUQxA6W0UpuF6DEDqhWpo16MMQOudwCrNzAxA7LUW7cL1DEDuzWyvuB4NQO\u002flwnGuRw1A8P0YNKRwDUDyFW\u002f2mZkNQPMtxbiPwg1A9EUbe4XrDUD1XXE9exQOQPd1x\u002f9wPQ5A+I0dwmZmDkD5pXOEXI8OQPq9yUZSuA5A\u002fNUfCUjhDkD97XXLPQoPQP4FzI0zMw9AAB4iUClcD0ABNngSH4UPQAJOztQUrg9AA2YklwrXD0ACP70sAAAQQANL6A17FBBABFcT7\u002fUoEEAEYz7QcD0QQAVvabHrURBABnuUkmZmEEAGh79z4XoQQAeT6lRcjxBAB58VNtejEEAIq0AXUrgQQAm3a\u002fjMzBBACcOW2UfhEEAKz8G6wvUQQAvb7Js9ChFAC+cXfbgeEUAM80JeMzMRQA3\\u002fCE0Ahf89kCtcTQCKL+kWF6xNAIpclJwAAFEAjo1AIexQUQCOve+n1KBRAJLumynA9FEAlx9Gr61EUQCXT\u002fIxmZhRAJt8nbuF6FEAn61JPXI8UQCf3fTDXoxRAKAOpEVK4FEApD9TyzMwUQCkb\u002f9NH4RRAKicqtcL1FEAqM1WWPQoVQCs\u002fgHe4HhVALEurWDMzFUAsV9Y5rkcVQC1jARspXBVALm8s\u002fKNwFUAue1fdHoUVQC+Hgr6ZmRVAMJOtnxSuFUAwn9iAj8IVQDGrA2IK1xVAMbcuQ4XrFUA ...

# %% [markdown]
# # Conclusions

# %% [markdown]
# Machine learning approaches to curve construction open the door to new ways of thinking about how to build yield curves. It seems that we are no longer constrained in practice to a particular set of interpolation rules; instead, we can learn features observed in the data. Still, as explained before, practitioners need to impose constraints: because we live in a discrete world of data, the selection of instantaneous forward-rate curves is an underdetermined problem. Therefore, an appropriate set of restrictions is needed to reduce the search space.
